# %%
from googleapiclient.discovery import build

api_key = "AIzaSyAgwzSCHzY0_nLZPzOzQ3jSoWatEI6Njsk"
youtube = build("youtube", "v3", developerKey=api_key)

def search_id_using_name(channel_name: str):
    request = youtube.search().list(
        q = channel_name, 
        type = "channel",
        part = "id, snippet", 
        maxResults = 1
    )
    response = request.execute()
    channel_id = response["items"][0]["id"]["channelId"]
    
    return channel_id

# %%
channel_id = search_id_using_name("madan gowri")

# %%
def get_channel_stats(channel_id: str):
    """ gets the channel name as the input and returns the channel statistics """
    request = youtube.channels().list(
        part = "statistics, snippet", 
        id = channel_id
    )
    response_body = request.execute()
    #stats = response_body["items"][0]["statistics"]
    return response_body["items"][0]["snippet"]["localized"]

# %%
get_channel_stats("UC8butISFwT-Wl7EV0hUK0BQ")
# Out:
# {'title': 'freeCodeCamp.org', 'description': 'Learn to code for free.'}

# %%
from scripts.youtube_api import get_channel_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from scripts.youtube_api import get_channel_data
#
# File ~/D/projects/youtube/scripts/__init__.py:1
# ----> 1 from youtube_api import *
#
# ModuleNotFoundError: No module named 'youtube_api'

# %%
import json
def get_channel_data(channel_id: str):
    """ gets the channel name as the input and returns the channel statistics """
    request = youtube.channels().list(
        part = "statistics, snippet, id", 
        id = channel_id, 
        maxResults = 10
    )
    response_body = request.execute()
    stats = response_body["items"][0]["statistics"]
    channel_details = response_body["items"][0]["snippet"]["localized"]
    return response_body

# %%
with open("data2.json", "w") as file:
    json.dump(get_channel_data("UCY6KjrDBN_tIRFT_QNqQbRQ"), file, indent=4)

# %%
def get_video_details(id: str):
    
    request = youtube.videos().list(
        part = "snippet, statistics, contentDetails", 
        id = id
    ).execute()
    
    with open("data2.json", "w") as file:
        json.dump(request, file)

playlist_id = get_video_details(channel_id)

# %%
search_id_using_name("madan gowri")
# Out:
# 'UCY6KjrDBN_tIRFT_QNqQbRQ'

# %%
def get_playlist_id(channel_id: str):
    response = youtube.channels().list(
        part='contentDetails',
        id=channel_id
    ).execute()
    
    return response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

playlist_id = get_playlist_id("UCY6KjrDBN_tIRFT_QNqQbRQ")
playlist_id
# Out:
# 'UUY6KjrDBN_tIRFT_QNqQbRQ'

# %%
import json
def get_videos_data(uploads_id: str):
    
    next_page_token = None
    while True:
        request = youtube.playlistItems().list(
            playlistId = uploads_id, 
            part = "snippet", 
            maxResults = 50, 
            pageToken = next_page_token
        )
        response = request.execute()
        
        next_page_token = response.get("nextPageToken")
        if next_page_token is None:
            break
    return response

# %%
len(mg_data)
# Out:
# 5

# %%
uploads_id = get_playlist_id(channel_id)
data = get_video_details(uploads_id)
with open("data2.json", "w") as file:
    json.dump(data, file)

# %%
get_playlist_id()

# %%
def video_details(playlist_id: str, max_results: int):    
    response = youtube.playlistItems().list(
        part = "snippet", 
        playlistId = playlist_id, 
        maxResults = max_results
    ).execute()
    response = [response]
    
   #video_ids = []
    #for i in response:
     #   video_ids.append(response[i]["items"][0]["id"])
      #  print(i)"""
    return response
        
mg_id = search_id_using_name("madan gowri")
playlist_id = get_playlist_id(mg_id)
details = video_details(playlist_id, 5)

# %%
video_details("UUY6KjrDBN_tIRFT_QNqQbRQ")

# %% [markdown]
# ### 1. first find the channel id by calling the "search_id_using_name" function
# ### 2. find the uploads playlist of the required channel using "get_playlist_id" function
# ### 3. find the video details using "video details" function

# %%
mg_id = search_id_using_name("madan gowri")
playlist_id = get_playlist_id(mg_id)
details = video_details(playlist_id, 5)
details
# Out:
# 'VVVZNktqckRCTl90SVJGVF9RTnFRYlJRLnI0VGZNVDhQMlZJ'

# %%
def get_video_stats(video_id: str):
    response = youtube.videos().list(
        id = details, 
        part = "statistics"
    ).execute()
    
    return response
get_video_stats(details)
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'YIUPVpqNjppyCWOZfL-19bLb7uk',
#  'items': [],
#  'pageInfo': {'totalResults': 0, 'resultsPerPage': 0}}

# %%
mg_id = search_id_using_name("madan gowri")
playlist_id = get_playlist_id(mg_id)
get_videos_data(playlist_id)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[102], line 3
#       1 mg_id = search_id_using_name("madan gowri")
#       2 playlist_id = get_playlist_id(mg_id)
# ----> 3 get_videos_data(playlist_id)
#
# Cell In[40], line 15, in get_videos_data(uploads_id)
#       7 request = youtube.playlistItems().list(
#       8     playlistId = uploads_id,
#       9     part = "snippet",
#      10     maxResults = 50,
#      11     pageToken = next_page_token
#      12 )
#      13 response = request.execute()
# ---> 15 videos += response["items"]
#      16 next_page_token = response.get("nextPageToken")
#      17 if next_page_token is None:
#
# UnboundLocalError: local variable 'videos' referenced before assignment

# %%
search_id_using_name("madan gowri")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 search_id_using_name("madan gowri")
#
# NameError: name 'search_id_using_name' is not defined

# %%
playlist_id = get_playlist_id(channel_id)
playlist_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 playlist_id = get_playlist_id(channel_id)
#       2 playlist_id
#
# NameError: name 'get_playlist_id' is not defined

# %%
data = open("data2.json", "r").read()

# %%
import json
with open("data5.json", "w") as file:
    json.dump(data, file, indent=4)

# %%
with open("data5.json", "r") as file:
    json_data = json.load(file)

# %%
def extract_required_data():
    """ extracting the required data """
    
    data = open("data2.json", "r").read()

# %%
from googleapiclient.discovery import build
import os

# Set up the YouTube Data API credentials
api_key = "AIzaSyAgwzSCHzY0_nLZPzOzQ3jSoWatEI6Njsk"
youtube = build('youtube', 'v3', developerKey=api_key)

def scrape_channel_video_ids(playlist_id: str):
    video_ids = []

    # Retrieve video data for the channel
    next_page_token = None
    while True:
        response = youtube.playlistItems().list(
            playlistId=playlist_id,
            part = "snippet", 
            maxResults=50,
            pageToken=next_page_token
        ).execute()

        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    return response

playlist_id = get_playlist_id(channel_id)
video_ids = scrape_channel_video_ids(playlist_id)
with open("playlist_id.json", "w") as file:
    json.dump(video_ids, file, indent=4)

# %%
from googleapiclient.discovery import build

apiKey = "AIzaSyAgwzSCHzY0_nLZPzOzQ3jSoWatEI6Njsk"
youtube = build("youtube", "v3", developerKey = apiKey)

def getVideoDetails(videoId: str):
    
    request = youtube.videos().list(
            id = videoId, 
            part = "snippet, contentDetails, statistics"
        )
    response = request.execute()
    
    return response

# %%
getVideoDetails("DzwVmEvgR6E")
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'P7OuuP74HjW857xfFAJ5NFHdVT0',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'jJQvjT13w26PxKWLDsHJUlib8NA',
#    'id': 'DzwVmEvgR6E',
#    'snippet': {'publishedAt': '2023-05-28T16:41:26Z',
#     'channelId': 'UCY6KjrDBN_tIRFT_QNqQbRQ',
#     'title': '🔴 AGAIN 😭 Non Stop Rain 🌧️ | CSKvGT | Madan Gowri | MG',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DzwVmEvgR6E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DzwVmEvgR6E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DzwVmEvgR6E/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/DzwVmEvgR6E/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/DzwVmEvgR6E/maxresdefault.jpg',
#       'width': 1280,
# ...

# %%
from googleapiclient.discovery import build

apiKey = "AIzaSyAgwzSCHzY0_nLZPzOzQ3jSoWatEI6Njsk"
YOUTUBE = build("youtube", "v3", developerKey=apiKey)

def getVideoIds(PlaylistId: str) -> list:
    """

    Parameters
    ----------
    PlaylistId: playlist id of a YouTube channel

    Returns: list of video ids of the given YouTube channel
    -------

    """
    videoDetails = []
    nextpageToken = None

    while True:
        request = YOUTUBE.playlistItems().list(
            playlistId=PlaylistId,
            part="snippet",
            maxResults=50,
            pageToken=nextpageToken
        )
        response = request.execute()
        videoDetails += response["items"]

        nextpageToken = response.get('nextPageToken')
        if nextpageToken is None:
            break

    videoIds = []
    for video in videoDetails:
        _id = video["snippet"]["resourceId"]["videoId"]
        videoIds.append(_id)

    return videoIds

# %%
video_ids = getVideoIds("UUY6KjrDBN_tIRFT_QNqQbRQ")

# %%
video_ids
# Out:
# ['qS8IqXJ8bRk',
#  'LWAykncV_DI',
#  'CDZXLN-azEI',
#  'rfhLTQyswd8',
#  'y6mDaEKa-Gc',
#  '_xc5VvXLRm8',
#  'DzwVmEvgR6E',
#  '8pmMsSlKI0Q',
#  '5yrndZoRi-A',
#  '8xvecMePGhs',
#  'cz_HvTN_OoQ',
#  'A4ztMboAfX4',
#  'IzKTdt8kSbo',
#  'WwjErQIadkw',
#  '5G3wmp3wL4I',
#  'wwoBIDlVVV0',
#  'WVGbHhRGUKM',
#  'NoXQXiCRusw',
#  'A8vuyCp7nFo',
#  '7WIJWa-C4TQ',
#  '-7pNX-UW0NY',
#  'r4TfMT8P2VI',
#  '1g8IoF_DDI8',
#  '8zlW9g-AKbE',
#  'B_JoPhcBCqI',
#  'kE1f7iY1nyE',
#  '-LGmuHum8AE',
#  'VY7EctMMbJ8',
#  'rmvoe55kIIY',
#  'z-yv6Ig-ItE',
#  'y33Krlheoyg',
#  '7TTVYsox2ug',
#  'hjEc5RH56ak',
#  'SHKQCW0DWjE',
#  'buH7837JSOw',
#  'rCj5ZSpYda4',
#  'oobQTsOufk4',
#  'iBcw6jBoFlM',
#  '3Frve-dG-Wc',
#  '_ypa1YuABoI',
#  '7HDW2Dsxk0U',
#  'Bp_4-uheCD8',
#  '_uQEZPOJmw4',
#  'E5ZNRuWwZW4',
#  'Ja7XU_VPhpg',
#  'B06i6kyNVSY',
#  '5MpISJUDCeM',
#  'uDFOyhEAPZM',
#  '1TY_APW8JN4',
#  'yjp8Hr6D7SM',
#  'ubU98Zh4CYM',
#  'RZI4r1hYm8k',
#  'NUFoiIO4xhE',
#  '4jU8Pk8W-Hw',
#  'ge4AZk77R0I',
# ...

# %%
len(video_ids)
# Out:
# 2215

# %%
def makeVideoDetailsAndComments():
    

    videoDetailsResponse = video_ids[1]
    commentsResponse = video_ids[1]

    totalComments = []
    for index, value in enumerate(commentsResponse["items"]):
        comment = {
            f"comment_id_{index}": {
                "comment_id": value["id"],
                "comment_text": value["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                "comment_author": value["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                "comment_publishedAt": value["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
            }
        }
        totalComments.append(comment)


    Video_details = {
        "video_id": videoDetailsResponse["items"][0]["id"],
        "video_name": videoDetailsResponse["items"][0]["snippet"]["title"],
        "video_description": videoDetailsResponse["items"][0]["snippet"]["description"],
        "publishedAt": videoDetailsResponse["items"][0]["snippet"]["publishedAt"],
        "view_count": videoDetailsResponse["items"][0]["statistics"]["viewCount"],
        "favorite_count": videoDetailsResponse["items"][0]["statistics"]["favoriteCount"],
        "comment_count": videoDetailsResponse["items"][0]["statistics"]["commentCount"],
        "duration": videoDetailsResponse["items"][0]["contentDetails"]["duration"],
        "thumbnail": videoDetailsResponse["items"][0]["snippet"]["thumbnails"]["maxres"]["url"],
        "comments": totalComments
    }

    return Video_details


def combineData(channelName: str):
    data = {
        "channel_name": makeChannelDetails(),
        "video_id_1": makeVideoDetailsAndComments()
    }

    return data

# %%
data = combineData()

# %%
def makeVideoDetailsAndComments(channelName: str):
    channel_id = getChannelIdByName(channelName) # channel id
    playlist_id = getPlaylistId(channel_id) # playlist id
    video_ids = getVideoIds(playlist_id) # list of video ids

    totalVideoDetails = []
    for number, ids in enumerate(video_ids):

        videoDetailsResponse = getVideoDetails(ids)
        commentsResponse = getComments(ids)

        totalComments = []
        for index, value in enumerate(commentsResponse["items"]):

            comment = {
                f"comment_id_{index}": {
                    "comment_id": value["id"],
                    "comment_text": value["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                    "comment_author": value["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                    "comment_publishedAt": value["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
                }
            }
            totalComments.append(comment)

        video_details = {
            f"video_id_{number}":{
                "video_id": videoDetailsResponse["items"][0]["id"],
                "video_name": videoDetailsResponse["items"][0]["snippet"]["title"],
                "video_description": videoDetailsResponse["items"][0]["snippet"]["description"],
                "publishedAt": videoDetailsResponse["items"][0]["snippet"]["publishedAt"],
                "view_count": videoDetailsResponse["items"][0]["statistics"]["viewCount"],
                "favorite_count": videoDetailsResponse["items"][0]["statistics"]["favoriteCount"],
                "comment_count": videoDetailsResponse["items"][0]["statistics"]["commentCount"],
                "duration": videoDetailsResponse["items"][0]["contentDetails"]["duration"],
                "thumbnail": videoDetailsResponse["items"][0]["snippet"]["thumbnails"]["high"]["url"],
                "comments": totalComments
            }
        }
        totalVideoDetails.append(video_details)
    return totalVideoDetails


def combineData(channelName: str):
    data = {
        "channel_name": makeChannelDetails(channelName),
        "video_id_1": makeVideoDetailsAndComments(channelName)
    }

    return data


if __name__ == '__main__':

    data = makeVideoDetailsAndComments("madan gowri")
    with open("total_details.json", "w") as file:
        json.dump(data, file, indent=4)

# %%
        if "commentCount" in videoData["items"][0]["statistics"]:
            commentCount = videoData["items"][0]["statistics"]["commentCount"]
        else:
            commentCount = 0
        video = {
            f"video_id_{index}":{
                "video_id": videoData["items"][0]["id"],
                "video_name": videoData["items"][0]["snippet"]["title"],
                "video_description": videoData["items"][0]["snippet"]["description"],
                "publishedAt": videoData["items"][0]["snippet"]["publishedAt"],
                "view_count": videoData["items"][0]["statistics"]["viewCount"],
                "favorite_count": videoData["items"][0]["statistics"]["favoriteCount"],
                "comment_count": commentCount,
                "duration": videoData["items"][0]["contentDetails"]["duration"],
                "thumbnail": videoData["items"][0]["snippet"]["thumbnails"]["high"]["url"],
                "comments": commentsList

# %%
data = {
    "a":1
}
if "b" not in data:
    value = 0
else:
    value = data["b"]
    
video_data = {
    "value":value
}
video_data
# Out:
# {'value': 0}

# %%
videoAndCommentsDataList = []
    for index, _id in enumerate(video_ids):
        videoData = getVideoDetails(_id) # this variable has the video details

        commentsList = [] # the ist where all the comments gets appended
        #commentsCount = videoData["items"][0]["statistics"]["commentCount"]

        try:
            itemsDetails = videoData.get("items", [])
            if not itemsDetails or "commentCount" in itemsDetails[0]["snippet"] and itemsDetails[0]["snippet"]["commentCount"] == "0":
                commentCount = videoData["items"][0]["statistics"]["commentCount"]
            else:
               commentCount = 0
        except:
            pass

        if commentCount == 0:
            commentsList = []
        else:
            commentsData = getComments(_id) # this variable has the comments data
            for number, comment in enumerate(commentsData["items"]):
                commentDictionary = {
                    f"comment_id_{number}":{
                        "comment_id": comment["id"],
                        "comment_text": comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                        "comment_author": comment["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                        "comment_publishedAt": comment["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
                    }
                }
                commentsList.append(commentDictionary)

        """if "commentCount" in videoData["items"][0]["statistics"]:
            commentCount = videoData["items"][0]["statistics"]["commentCount"]
        else:
            commentCount = 0"""
        video = {
            f"video_id_{index}":{
                "video_id": videoData["items"][0]["id"],
                "video_name": videoData["items"][0]["snippet"]["title"],
                "video_description": videoData["items"][0]["snippet"]["description"],
                "publishedAt": videoData["items"][0]["snippet"]["publishedAt"],
                "view_count": videoData["items"][0]["statistics"]["viewCount"],
                "favorite_count": videoData["items"][0]["statistics"]["favoriteCount"],
                "comment_count": commentCount,
                "duration": videoData["items"][0]["contentDetails"]["duration"],
                "thumbnail": videoData["items"][0]["snippet"]["thumbnails"]["high"]["url"],
                "comments": commentsList
            }
        }
        videoAndCommentsDataList.append(video)

    # "videoAndCommentsDataList" varibale contains the video and comments data
    return videoAndCommentsDataList

# %%
if videoData["items"][0]["statistics"]["commentCount"] == "0":
            commentCount = 0
            comments = "comments disabled"
            commentsList.append(comments)
        
        else:
            commentCount = videoData["items"][0]["statistics"]["commentCount"]
            for number, _id in enumerate(video_ids):
                request = YOUTUBE.commentThreads().list(
                    part='snippet',
                    videoId=_id,
                    textFormat='plainText',
                    maxResults=1
                )
                comments = request.execute()
                commentDictionary = {
                    f"comment_id_{number}":{
                        "comment_id": comments["items"][0]["id"], 
                        "comment_text": comments["items"][0]["snippet"]["topLevelComment"]["snippet"]["textDisplay"], 
                        "comment_author": comments["items"][0]["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"], 
                        "comment_publishedAt": comments["items"][0]["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
                    }
                }
                commentsList.append(commentDictionary)
        
        videoDataDictionary = {
            f"video_id_{index}":{
                "video_id": videoData["items"][0]["id"],
                "video_name": videoData["items"][0]["snippet"]["title"],
                "video_description": videoData["items"][0]["snippet"]["description"],
                "publishedAt": videoData["items"][0]["snippet"]["publishedAt"],
                "view_count": videoData["items"][0]["statistics"]["viewCount"],
                "favorite_count": videoData["items"][0]["statistics"]["favoriteCount"],
                "comment_count": commentCount,
                "duration": videoData["items"][0]["contentDetails"]["duration"],
                "thumbnail": videoData["items"][0]["snippet"]["thumbnails"]["high"]["url"],
                "comments": commentsList
        }
            }
        totalVideoData.append(videoDataDictionary)
